# %%
import pandas as pd
import numpy as np
train=pd.read_csv("zomato.csv")
td=pd.DataFrame(train)
td
# Out:
#       Restaurant ID                           Restaurant Name  Country Code  \
# 0           6317637                          Le Petit Souffle           162
# 1           6304287                          Izakaya Kikufuji           162
# 2           6300002                    Heat - Edsa Shangri-La           162
# 3           6318506                                      Ooma           162
# 4           6314302                               Sambo Kojin           162
# 5          18189371                              Din Tai Fung           162
# 6           6300781                                Buffet 101           162
# 7           6301290                                   Vikings           162
# 8           6300010  Spiral - Sofitel Philippine Plaza Manila           162
# 9           6314987                                  Locavore           162
# 10          6309903                          Silantro Fil-Mex           162
# ...

# %%
from sklearn import preprocessing
x=preprocessing.LabelEncoder()
for col in td.columns:
    td[col]=x.fit_transform(td[col])
    print(td[col])
# Out:
# 0       2309
# 1       2299
# 2       2295
# 3       2312
# 4       2305
# 5       3005
# 6       2297
# 7       2298
# 8       2296
# 9       2307
# 10      2302
# 11      2301
# 12      2311
# 13      2304
# 14      2306
# 15      3004
# 16      3003
# 17      2310
# 18      3175
# 19      2300
# 20      2308
# 21      2303
# 22      2321
# 23      2323
# 24      2317
# 25      2320
# 26      2322
# 27      2318
# 28      2316
# 29      2325
#         ...
# 4469    3008
# 4470    1840
# 4471    4284
# 4472     593
# 4473    1777
# 4474     792
# 4475     791
# 4476    4470
# 4477     693
# 4478    1514
# 4479    3051
# 4480    1704
# 4481    1120
# 4482     513
# 4483    3508
# 4484    3980
# 4485    3405
# 4486    1208
# 4487     790
# 4488     595
# 4489    3649
# 4490    3133
# 4491    1685
# 4492    1654
# 4493    3427
# 4494     594
# 4495     831
# 4496    3520
# 4497     243
# 4498    3709
# Name: Restaurant ID, Length: 4499, dtype: int64
# 0       1926
# 1       1635
# ...

# %%
td.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4499 entries, 0 to 4498
# Data columns (total 21 columns):
# Restaurant ID           4499 non-null int64
# Restaurant Name         4499 non-null int64
# Country Code            4499 non-null int64
# City                    4499 non-null int64
# Address                 4499 non-null int64
# Locality                4499 non-null int64
# Locality Verbose        4499 non-null int64
# Longitude               4499 non-null int64
# Latitude                4499 non-null int64
# Cuisines                4490 non-null object
# Average Cost for two    4499 non-null int64
# Currency                4499 non-null object
# Has Table booking       4499 non-null object
# Has Online delivery     4499 non-null object
# Is delivering now       4499 non-null object
# Switch to order menu    4499 non-null object
# Price range             4499 non-null int64
# Aggregate rating        4499 non-null float64
# Rating color            4499 non-null object
# ...

# %%
#num=['Restaurant Name','City','Address','Locality','Locality Verbose','Cuisines','Currency','Has Table booking','Has Online delivery','Is delivering now','Switch to order menu','Rating color','Rating text']
#=train[list(num)].values
#print(pd.to_numeric(x, errors='coerce'))
#train.City=train.City.astype(float)

# %%
td.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name           int64
# Country Code              int64
# City                      int64
# Address                   int64
# Locality                  int64
# Locality Verbose          int64
# Longitude                 int64
# Latitude                  int64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %%
td.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
td.describe()
# Out:
#        Restaurant ID  Restaurant Name  Country Code         City      Address  \
# count     4499.00000      4499.000000    4499.00000  4499.000000  4499.000000
# mean      2249.00000      1842.337631       0.83174    56.314737  2138.897088
# std       1298.89376      1076.542074       2.18455    22.821072  1206.278978
# min          0.00000         0.000000       0.00000     0.000000     0.000000
# 25%       1124.50000       903.500000       0.00000    41.000000  1106.500000
# 50%       2249.00000      1822.000000       0.00000    73.000000  2187.000000
# 75%       3373.50000      2776.500000       0.00000    74.000000  3158.500000
# max       4498.00000      3741.000000       7.00000   109.000000  4221.000000
#
#           Locality  Locality Verbose    Longitude     Latitude  \
# count  4499.000000       4499.000000  4499.000000  4499.000000
# mean    340.083352        347.993110  1879.179818  1973.623916
# std     201.606373        207.027168  1099.676452  1224.985535
# ...

# %%
td['Restaurant Name'].value_counts()
# Out:
# 566     37
# 1074    31
# 2090    25
# 3065    24
# 308     21
# 1401    16
# 1098    14
# 2784    13
# 2536    13
# 1449    12
# 1349    12
# 1791    12
# 3053    12
# 314     11
# 1348    11
# 321     10
# 899     10
# 686     10
# 2514    10
# 1296     9
# 2210     9
# 3636     8
# 1711     8
# 2707     7
# 525      7
# 2159     7
# 2915     6
# 333      6
# 1755     6
# 523      6
#         ..
# 3115     1
# 3171     1
# 3175     1
# 1182     1
# 1158     1
# 3227     1
# 1178     1
# 3223     1
# 1174     1
# 3219     1
# 1170     1
# 3215     1
# 1166     1
# 3211     1
# 1162     1
# 3207     1
# 3203     1
# 1130     1
# 1154     1
# 3199     1
# 1150     1
# 3195     1
# 1146     1
# 1142     1
# 3187     1
# 1138     1
# 3183     1
# 1134     1
# 3179     1
# 0        1
# Name: Restaurant Name, Length: 3742, dtype: int64

# %%
td.isnull().any()
# Out:
# Restaurant ID           False
# Restaurant Name         False
# Country Code            False
# City                    False
# Address                 False
# Locality                False
# Locality Verbose        False
# Longitude               False
# Latitude                False
# Cuisines                 True
# Average Cost for two    False
# Currency                False
# Has Table booking       False
# Has Online delivery     False
# Is delivering now       False
# Switch to order menu    False
# Price range             False
# Aggregate rating        False
# Rating color            False
# Rating text             False
# Votes                   False
# dtype: bool

# %%
td.fillna(0,inplace=True)
